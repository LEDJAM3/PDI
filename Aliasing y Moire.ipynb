# %% [markdown]
# Aliasing
#
# El aliasing es el efecto que causa que señales continuas distintas se tornen indistinguibles cuando se muestrean digitalmente. Cuando esto sucede, la señal original no puede ser reconstruida de forma unívoca a partir de la señal digital.
#
# https://es.wikipedia.org/wiki/Aliasing

# %% [markdown]
# Patrones de Moire
#
# El aliasing puede dar lugar a patrones Moiré. El patrón Moiré aparece cuando el nivel de textura o detalle de una escena es muy elevado. Puede describirse como un efecto de percepción visual que se da cuando observamos un conjunto de líneas o de puntos que se superponen unos con otros.
#
# https://www.fotonostra.com/fotografia/moire.htm

# %% [markdown]
# Imagen 1

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

def convMediaHor(imagen, tamanioK):
    kernel = np.ones((1, tamanioK), np.float32) / tamanioK
    kernel2 = np.ones((tamanioK, 1), np.float32) / tamanioK
    imgFin = cv2.filter2D(imagen, -1, kernel)
    imgFin = cv2.filter2D(imgFin, -1, kernel2)
    return imgFin

imagen = cv2.imread("AM1.jpeg")

gris = cv2.cvtColor(imagen, cv2.COLOR_BGR2RGB)

img = convMediaHor(gris, 5)

plt.figure(figsize=(15, 10))
plt.subplot(121)
plt.title("Imagen Original")
plt.axis("off")
plt.imshow(cv2.cvtColor(imagen, cv2.COLOR_BGR2RGB))

plt.subplot(122)
plt.title("Imagen Filtrada")
plt.axis("off")
plt.imshow(img)
plt.show()

# %% [markdown]
# Imagen 2

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

def convMediaHor(imagen, tamanioK):
    kernel = np.ones((1, tamanioK), np.float32) / tamanioK
    kernel2 = np.ones((tamanioK, 1), np.float32) / tamanioK
    imgFin = cv2.filter2D(imagen, -1, kernel)
    imgFin = cv2.filter2D(imgFin, -1, kernel2)
    return imgFin

imagen = cv2.imread("AM2.jpeg")

gris = cv2.cvtColor(imagen, cv2.COLOR_BGR2RGB)

img = convMediaHor(gris, 100)

plt.figure(figsize=(15, 10))
plt.subplot(121)
plt.title("Imagen Original")
plt.axis("off")
plt.imshow(cv2.cvtColor(imagen, cv2.COLOR_BGR2RGB))

plt.subplot(122)
plt.title("Imagen Filtrada")
plt.axis("off")
plt.imshow(img)
plt.show()

# %% [markdown]
# Imagen 3

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

def convMediaHor(imagen, tamanioK):
    kernel = np.ones((1, tamanioK), np.float32) / tamanioK
    kernel2 = np.ones((tamanioK, 1), np.float32) / tamanioK
    imgFin = cv2.filter2D(imagen, -1, kernel)
    imgFin = cv2.filter2D(imgFin, -1, kernel2)
    return imgFin

imagen = cv2.imread("AM3.jpeg")

gris = cv2.cvtColor(imagen, cv2.COLOR_BGR2RGB)

img = convMediaHor(gris, 5)

plt.figure(figsize=(15, 10))
plt.subplot(121)
plt.title("Imagen Original")
plt.axis("off")
plt.imshow(cv2.cvtColor(imagen, cv2.COLOR_BGR2RGB))

plt.subplot(122)
plt.title("Imagen Filtrada")
plt.axis("off")
plt.imshow(img)
plt.show()
